# %%
# Activate intractive functionality of matplotlib
# %matplotlib ipympl
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm, expon, logistic, cauchy, gamma, beta, weibull_min, uniform

# Set up the figure
fig, axes = plt.subplots(4, 2, figsize=(12, 14))
fig.subplots_adjust(hspace=0.5)

# Uniform Distribution
x_uniform = np.linspace(-1, 2, 1000)
pdf_uniform = uniform.pdf(x_uniform, loc=0, scale=1)
axes[0, 0].plot(x_uniform, pdf_uniform, label='Uniform')
axes[0, 0].set_title('Uniform Distribution')

# Normal Distribution
x_normal = np.linspace(-5, 5, 1000)
pdf_normal = norm.pdf(x_normal, loc=0, scale=1)
axes[0, 1].plot(x_normal, pdf_normal, label='Normal')
axes[0, 1].set_title('Normal Distribution')

# Exponential Distribution
x_exponential = np.linspace(0, 5, 1000)
pdf_exponential = expon.pdf(x_exponential, scale=1)
axes[1, 0].plot(x_exponential, pdf_exponential, label='Exponential')
axes[1, 0].set_title('Exponential Distribution')

# Logistic Distribution
x_logistic = np.linspace(-5, 5, 1000)
pdf_logistic = logistic.pdf(x_logistic)
axes[1, 1].plot(x_logistic, pdf_logistic, label='Logistic')
axes[1, 1].set_title('Logistic Distribution')

# Cauchy Distribution
x_cauchy = np.linspace(-5, 5, 1000)
pdf_cauchy = cauchy.pdf(x_cauchy)
axes[2, 0].plot(x_cauchy, pdf_cauchy, label='Cauchy')
axes[2, 0].set_title('Cauchy Distribution')

# Gamma Distribution
x_gamma = np.linspace(0, 5, 1000)
pdf_gamma = gamma.pdf(x_gamma, a=2, scale=1)
axes[2, 1].plot(x_gamma, pdf_gamma, label='Gamma')
axes[2, 1].set_title('Gamma Distribution')

# Beta Distribution
x_beta = np.linspace(0, 1, 1000)
pdf_beta = beta.pdf(x_beta, a=2, b=5)
axes[3, 0].plot(x_beta, pdf_beta, label='Beta')
axes[3, 0].set_title('Beta Distribution')

# Weibull Distribution
x_weibull = np.linspace(0, 5, 1000)
pdf_weibull = weibull_min.pdf(x_weibull, c=1)
axes[3, 1].plot(x_weibull, pdf_weibull, label='Weibull')
axes[3, 1].set_title('Weibull Distribution')

# Adjust layout and show the plots
plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import beta, gamma

# Set up the figure
fig, axes = plt.subplots(2, 2, figsize=(12, 8))
fig.subplots_adjust(hspace=0.5)

# Beta Distribution with different alpha and beta
x_beta = np.linspace(0, 1, 1000)
for a, b in [(1.1,5), (2, 5), (3, 5), (4,5), (5,5)]:
    pdf_beta = beta.pdf(x_beta, a, b)
    axes[0, 0].plot(x_beta, pdf_beta, label=f'Beta({a}, {b})')

axes[0, 0].set_title('Beta Distribution with Different Parameters')
axes[0, 0].legend()

# Gamma Distribution with different k and theta
x_gamma = np.linspace(0, 10, 1000)
for k, theta in [(1.001, 1), (1.01, 1),(1.05, 1),(1.1,1),(2, 1), (3, 1), (4, 1)]:
    pdf_gamma = gamma.pdf(x_gamma, k, scale=theta)
    axes[0, 1].plot(x_gamma, pdf_gamma, label=f'Gamma({k}, {theta})')

axes[0, 1].set_title('Gamma Distribution with Different Parameters')
axes[0, 1].legend()

# Beta Distribution with different alpha and beta
x_beta_single = np.linspace(0, 1, 1000)
pdf_beta_single = beta.pdf(x_beta_single, 2, 5)
axes[1, 0].plot(x_beta_single, pdf_beta_single, label='Beta(2, 5)')
axes[1, 0].set_title('Single Beta Distribution (Alpha=2, Beta=5)')
axes[1, 0].legend()

# Gamma Distribution with different k and theta
x_gamma_single = np.linspace(0, 10, 1000)
pdf_gamma_single = gamma.pdf(x_gamma_single, 3, scale=2)
axes[1, 1].plot(x_gamma_single, pdf_gamma_single, label='Gamma(3, 2)')
axes[1, 1].set_title('Single Gamma Distribution (k=3, theta=2)')
axes[1, 1].legend()

# Adjust layout and show the plots
plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import numpy as np
import matplotlib.pyplot as plt

# Arbitrary parameter values for the Gaussian function
mu = 0.2
sigma = 0.0001

# Define the Gaussian function with mean (mu) and standard deviation (sigma)
def gaussian(x, mu, sigma):
    return (1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * ((x - mu) / sigma)**2)

# Arbitrary parameter values for the exponential decay function
A = 0.3
B = 0.9

# Define the exponential decay function
def exp_decay(x):
    return np.exp(A ** (x * B))

# Generate a sample of x values
x_values = np.linspace(-2, 2, 1000)

# Compute the Gaussian function
gaussian_values = gaussian(x_values, mu, sigma)

# Compute the exponential decay function
decay_values = exp_decay(x_values)

# Convolve the Gaussian and exponential decay functions
convolved_pulse = np.convolve(gaussian_values, decay_values, mode='same') 

# Plot the individual functions and the convolved pulse
plt.figure(figsize=(10, 6))

plt.subplot(3, 1, 1)
plt.plot(x_values, gaussian_values, label='Gaussian Function')
plt.legend()

plt.subplot(3, 1, 2)
plt.plot(x_values, decay_values, label='Exponential Decay Function')
plt.legend()

plt.subplot(3, 1, 3)
plt.plot(x_values+4, convolved_pulse/max(convolved_pulse), label='Convolved Pulse')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
